# %%
# %sql
CREATE CATALOG IF NOT EXISTS metadata_governance;
CREATE SCHEMA IF NOT EXISTS metadata_governance.bronze;
CREATE SCHEMA IF NOT EXISTS metadata_governance.silver;
CREATE SCHEMA IF NOT EXISTS metadata_governance.gold;
