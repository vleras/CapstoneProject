# %%
# %sql
CREATE CATALOG IF NOT EXISTS metadata_governance_test;
CREATE SCHEMA IF NOT EXISTS metadata_governance_test.bronze;
CREATE SCHEMA IF NOT EXISTS metadata_governance_test.silver;
CREATE SCHEMA IF NOT EXISTS metadata_governance_test.gold;
