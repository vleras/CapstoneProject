# %%
# %sql
--Grant permissions to the group for catalog
GRANT USE CATALOG ON CATALOG metadata_governance TO `capstone_team`;
GRANT USE SCHEMA ON SCHEMA metadata_governance.bronze TO `capstone_team`;
GRANT USE SCHEMA ON SCHEMA metadata_governance.silver TO `capstone_team`;
GRANT USE SCHEMA ON SCHEMA metadata_governance.gold TO `capstone_team`;
GRANT SELECT ON SCHEMA metadata_governance.bronze TO `capstone_team`;
GRANT SELECT ON SCHEMA metadata_governance.silver TO `capstone_team`;
GRANT SELECT ON SCHEMA metadata_governance.gold TO `capstone_team`;
GRANT CREATE TABLE ON SCHEMA metadata_governance.bronze TO `capstone_team`;
GRANT CREATE TABLE ON SCHEMA metadata_governance.silver TO `capstone_team`;
GRANT CREATE TABLE ON SCHEMA metadata_governance.gold TO `capstone_team`;

# %%
# %sql
--Grant permissions to the group for external location
GRANT READ FILES ON EXTERNAL LOCATION `db_s3_external_databricks-s3-ingest-f917f` TO `capstone_team`;
